# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import seaborn as sns
import networkx as nx
from networkx.algorithms import bipartite
from sklearn import datasets, linear_model, metrics 
from sklearn.model_selection import train_test_split
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
geolocator = Nominatim(user_agent="my-application")

# %%
data=pd.read_csv('SCI data/SCI Data/County_country.csv')

# %%
data
# Out:
#         own_county friend_country  sci_cntry  rel_prob_friend_cntry country  \
# 0             1001             AE       1386               2.524268     USA
# 1             1001             AF       4776               8.698344     USA
# 2             1001             AL        724               1.318593     USA
# 3             1001             AM         99               0.180305     USA
# 4             1001             AO       1462               2.662684     USA
# 5             1001             AR        697               1.269419     USA
# 6             1001             AT        907               1.651884     USA
# 7             1001             AU       1254               2.283862     USA
# 8             1001             AZ        879               1.600889     USA
# 9             1001             BA        424               0.772215     USA
# 10            1001             BD        428               0.779500     USA
# ...

# %%
arr=data.values

# %%
co={}
for i in set(list(arr[:,1])):
    print(i, list(arr[:,1]).count(i))
# Out:
# nan 3136
# ID 3136
# BD 3136
# SK 3136
# UA 3136
# AO 3136
# LB 3136
# AU 3136
# GM 3136
# SZ 3136
# AR 3136
# NE 3136
# ZA 3136
# SA 3136
# BI 3136
# CH 3136
# OM 3136
# BO 3136
# PY 3136
# TD 3136
# BR 3136
# CF 3136
# UG 3136
# BE 3136
# SD 3136
# AT 3136
# BW 3136
# AF 3136
# ES 3136
# MK 3136
# SI 3136
# JM 3136
# SL 3136
# BY 3136
# KH 3136
# VE 3136
# CY 3136
# IR 3136
# BJ 3136
# MD 3136
# DZ 3136
# LR 3136
# KE 3136
# LA 3136
# PL 3136
# FR 3136
# SY 3136
# ET 3136
# PT 3136
# KG 3136
# GQ 3136
# XK 3136
# HN 3136
# IL 3136
# MZ 3136
# MY 3136
# RW 3136
# NL 3136
# CI 3136
# BA 3136
# GN 3136
# GW 3136
# EE 3136
# SN 3136
# ZW 3136
# TN 3136
# CR 3136
# CN 3136
# ER 3136
# PK 3136
# YE 3136
# LK 3136
# JO 3136
# AL 3136
# CD 3136
# NZ 3136
# CO 3136
# TG 3136
# EG 3136
# TT 3136
# NO 3136
# KR 3136
# RS 3136
# TR 3136
# NP 3136
# CU 3136
# TW 3136
# SG 3136
# LY 3136
# RU 3136
# SO 3136
# LV 3136
# BG 3136
# MM 3136
# TZ 3136
# MR 3136
# AE 3136
# MU 3136
# KW 3136
# ...

# %%
d={}
i=0
for row in arr:
    d.update({row[1]:i})
    i=i+1

# %%
d
# Out:
# {'AE': 492195,
#  'AF': 492196,
#  'AL': 492197,
#  'AM': 492198,
#  'AO': 492199,
#  'AR': 492200,
#  'AT': 492201,
#  'AU': 492202,
#  'AZ': 492203,
#  'BA': 492204,
#  'BD': 492205,
#  'BE': 492206,
#  'BF': 492207,
#  'BG': 492208,
#  'BI': 492209,
#  'BJ': 492210,
#  'BO': 492211,
#  'BR': 492212,
#  'BW': 492213,
#  'BY': 492214,
#  'CA': 492215,
#  'CD': 492216,
#  'CF': 492217,
#  'CG': 492218,
#  'CH': 492219,
#  'CI': 492220,
#  'CL': 492221,
#  'CM': 492222,
#  'CN': 492223,
#  'CO': 492224,
#  'CR': 492225,
#  'CU': 492226,
#  'CY': 492227,
#  'CZ': 492228,
#  'DE': 492229,
#  'DK': 492230,
#  'DO': 492231,
#  'DZ': 492232,
#  'EC': 492233,
#  'EE': 492234,
#  'EG': 492235,
#  'ER': 492236,
#  'ES': 492237,
#  'ET': 492238,
#  'FI': 492239,
#  'FR': 492240,
#  'GA': 492241,
#  'GB': 492242,
#  'GE': 492243,
#  'GH': 492244,
#  'GM': 492245,
#  'GN': 492246,
#  'GQ': 492247,
#  'GR': 492248,
#  'GT': 492249,
#  'GW': 492250,
#  'HK': 492251,
#  'HN': 492252,
# ...

# %%
list(arr[:,1]).count('nan')
# Out:
# 0

# %%
co

# %%
for i in range (8):
    t={}
    for row in arr[:,i]:
        t.update({row:'p'})
        
    print(len(t))

# %%
d12=[]
for row in arr:
    

    d12.append(geodesic(crlg[row[1]], statloc[catostat[row[7]]]).miles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-78929a7cdd6e> in <module>
#       3
#       4
# ----> 5     d12.append(geodesic(crlg[row[1]], statloc[catostat[row[7]]]).miles)
#
# NameError: name 'crlg' is not defined

# %%
caunt=set(list(arr[:,7]))
state=set(list(arr[:,6]))
cuntr=set(list(arr[:,1]))

# %%
p12=[]
for row in arr:

    try:
        p12.append(row[2]/row[3])
    except ZeroDivisionError:
        p12.append(0)

# %%
#import statsmodels.api as sm

#y = [1,2,3,4,3,4,5,4,5,5,4,5,4,5,4,5,6,5,4,5,4,3,4]

#x1 = np.array([
     [4,2,3,4,5,4,5,6,7,4,8,9,8,8,6,6,5,5,5,5,5,5,5],
     [4,1,2,3,4,5,6,7,5,8,7,8,7,8,7,8,7,7,7,7,7,6,5],
     [4,1,2,5,6,7,8,9,7,8,7,8,7,7,7,7,7,7,6,6,4,4,4]])

def reg_m(y, x):
    ones = np.ones(len(x[0]))
    X = sm.add_constant(np.column_stack((x[0], ones)))
    for ele in x[1:]:
        X = sm.add_constant(np.column_stack((ele, X)))
    results = sm.OLS(y, X).fit()
    return results

# %%
p12
# Out:
# [549.0699800385728,
#  549.0700172568476,
#  549.0699823819823,
#  549.0699974398918,
#  549.0699948570693,
#  549.0699998865623,
#  549.0699983128357,
#  549.0699766041021,
#  549.0700259174795,
#  549.0700042629329,
#  549.0699940958299,
#  549.0699830736864,
#  549.069996480764,
#  549.0700126660469,
#  549.0700042399221,
#  549.0699832412695,
#  549.0700185069,
#  549.0700090407718,
#  549.0700200653666,
#  549.0699919031083,
#  549.0699968238047,
#  549.07001213449,
#  549.0699977708953,
#  549.0700077657486,
#  549.0700457131709,
#  549.0700022530227,
#  549.0700218017404,
#  549.0699909325537,
#  549.0699941854465,
#  549.07000821106,
#  549.070025593915,
#  549.0700011397051,
#  549.0699855004405,
#  549.0699974917698,
#  549.0700149545472,
#  549.0700001067947,
#  549.0700218017403,
#  549.0700043776155,
#  549.0699822137376,
#  549.0699857376947,
#  549.0700439575967,
#  549.0700028408675,
#  549.0699708477357,
#  549.0700151101978,
#  549.0699786371242,
# ...

# %%
q=[4,2,3,4,5,4,5,6,7,4,8,9,8,8,6,6,5,5,5,5,5,5,5]
w=[4,1,2,3,4,5,6,7,5,8,7,8,7,8,7,8,7,7,7,7,7,6,5]
e=[4,1,2,5,6,7,8,9,7,8,7,8,7,7,7,7,7,7,6,6,4,4,4]
x=[]
for i in range (23):
    x.append([q[i],w[i],e[i]])

# %%
x=np.array(x)

# %%
len(p12)-p12.count(0)
# Out:
# 477140

# %%
crcd=pd.read_csv('SCI data/database/uscities.csv')

# %%
crcd=crcd.values

# %%
crcd
# Out:
# array([['South Creek', 'South Creek', 'WA', ..., 3, '98580 98387 98338',
#         1840116412],
#        ['Roslyn', 'Roslyn', 'WA', ..., 3, '98941 98068 98925',
#         1840097718],
#        ['Sprague', 'Sprague', 'WA', ..., 3, '99032', 1840096300],
#        ...,
#        ['Emery', 'Emery', 'SD', ..., 3, '57332', 1840081745],
#        ['Watertown', 'Watertown', 'SD', ..., 3, '57201', 1840081993],
#        ['Buffalo', 'Buffalo', 'SD', ..., 3, '57720', 1840081693]],
#       dtype=object)

# %%
catostat={}
for i in arr:
    catostat.update({i[7]:i[6]})

# %%
len(crlg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-119769521125> in <module>
# ----> 1 len(crlg)
#
# NameError: name 'crlg' is not defined

# %%
len(calg)
# Out:
# 1906

# %%
d12
# Out:
# [7777.401856282503,
#  7557.685902578372,
#  5542.8552003825835,
#  6551.71949812379,
#  7465.135613918163,
#  5100.179452567264,
#  5071.478540280934,
#  9971.018388826542,
#  6631.170092419342,
#  5330.863661224602,
#  8555.197146811899,
#  4569.8590696601195,
#  5478.533461998571,
#  5698.383244611697,
#  7876.357422148217,
#  5808.52485648651,
#  3685.4498483408543,
#  3946.954278214313,
#  8226.417519131619,
#  5320.389664317686,
#  1886.0399857672496,
#  7432.033711177076,
#  6975.465429091461,
#  6945.68121869917,
#  4832.459643694703,
#  5415.433012546427,
#  4793.323872244937,
#  6458.586075604853,
#  7672.23461741423,
#  2080.9821906262127,
#  1580.3043250275941,
#  929.3816395092636,
#  6364.247356298306,
#  5027.739679379198,
#  4788.72292801475,
#  4602.933419482116,
#  1389.7245814380074,
#  5114.757310570865,
#  2427.6831989503935,
#  5028.3314298165515,
#  6632.660141499476,
#  7601.071490072249,
#  4464.841000422311,
#  7919.283657121639,
#  4918.144643554836,
# ...

# %%
crlg['UM']=(19.2823, 166.6470)

# %%
calg
# Out:
# {'Pierce': (31.3855, -82.1373),
#  'Kittitas': (47.2338, -121.0335),
#  'Lincoln': (43.4677, -96.6355),
#  'Snohomish': (48.0029, -122.096),
#  'Thurston': (42.116, -96.3667),
#  'Clallam': (48.0842, -123.1697),
#  'Ferry': (48.2622, -118.359),
#  'Okanogan': (48.3618, -120.1169),
#  'Wahkiakum': (46.3608, -123.589),
#  'Whatcom': (48.9135, -122.1048),
#  'Kitsap': (47.8978, -122.5579),
#  'Whitman': (46.9282, -117.6867),
#  'Skagit': (48.3357, -122.3444),
#  'Spokane': (47.703, -117.0854),
#  'Klickitat': (45.8192, -120.8233),
#  'Lewis': (38.5939, -83.3212),
#  'Cowlitz': (45.9149, -122.7503),
#  'Clark': (44.6279, -97.6387),
#  'Franklin': (38.1924, -84.8643),
#  'Grant': (45.0513, -96.5535),
#  'Stevens': (37.1745, -101.3447),
#  'Grays Harbor': (47.2502, -124.1903),
#  'Island': (48.2965, -122.6331),
#  'Skamania': (45.6944, -121.8932),
#  'Pend Oreille': (48.854, -117.3899),
#  'Chelan': (47.5948, -120.6633),
#  'Yakima': (46.4071, -120.5422),
#  'King': (33.6216, -100.329),
# ...

# %%
calg.update({'Kalawao':(21.1803, 156.9511)})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-28c6cc269e5e> in <module>
# ----> 1 calg.update({'Kalawao':(21.1803, 156.9511)})
#
# NameError: name 'calg' is not defined

# %%
for i in cuntr:
    if i=='SS':
        print('ee')
# Out:
# ee

# %%
crlg.update({'SS': (6.8770, 31.3070)})

# %%
len(statloc)
# Out:
# 52

# %%
len(p12), len(d12), len(list(arr[:,3]))
# Out:
# (492352, 492352, 492352)

# %%
X=[]
Y=[]
for i in range (len(p12)):
    
    if int(arr[i,3])!=0:
        
        k=arr[i,3]*d12[i]/p12[i]
        
        X.append([k, math.log(p12[i]), math.log(d12[i])])
        Y.append(math.log(arr[i,3]))

# %%
clf = linear_model.LinearRegression()
reg=clf.fit(np.array(X),Y)
clf.coef_
# Out:
# array([9.61545408e-06, 1.33140405e-01, 9.90021751e-02])

# %%
cofD={}
for st in state:
    X=[]
    Y=[]
    for i in range (len(p12)):
        if arr[i,6]!=st:

            if int(arr[i,3])!=0:

                k=arr[i,3]*d12[i]/p12[i]

                X.append([math.log(k), math.log(p12[i]), math.log(d12[i])])
                Y.append(math.log(arr[i,3]))
    X=np.array(X)
    clf = linear_model.LinearRegression()
    reg=clf.fit(X,Y)
    cofD.update({st:list(clf.coef_)})

    #print(X.shape)

# %%
cofD
# Out:
# {'North Dakota': [0.999999999999992, 1.0000000000000009, -0.9999999999999998],
#  'Tennessee': [0.9999999999999871, 0.9999999999999905, -1.0000000000000053],
#  'Idaho': [0.9999999999999928, 0.9999999999999953, -1.000000000000001],
#  'Minnesota': [1.000000000000004, 0.9999999999999982, -1.0000000000000073],
#  'Wisconsin': [1.0000000000000113, 1.00000000000001, -0.9999999999999973],
#  'Michigan': [0.999999999999999, 0.999999999999998, -0.9999999999999878],
#  'Montana': [1.0000000000000002, 0.9999999999999958, -0.9999999999999905],
#  'Illinois': [0.9999999999999992, 1.0000000000000022, -0.9999999999999926],
#  'New Hampshire': [1.0000000000000042,
#   0.9999999999999962,
#   -0.9999999999999982],
#  'New Jersey': [0.9999999999999997, 0.9999999999999989, -0.999999999999995],
#  'Utah': [0.9999999999999905, 0.9999999999999911, -1.0000000000000042],
#  'Hawaii': [0.9999999999999936, 1.0000000000000004, -0.9999999999999898],
# ...

# %%
# load the boston dataset 
boston = datasets.load_boston(return_X_y=False) 

# defining feature matrix(X) and response vector(y) 
X = boston.data 
y = boston.target 

# splitting X and y into training and testing sets 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4,random_state=1) 

# create linear regression object 
reg = linear_model.LinearRegression() 

# train the model using the training sets 
reg.fit(X_train, y_train) 

# regression coefficients 
print('Coefficients: \n', reg.coef_) 

# variance score: 1 means perfect prediction 
print('Variance score: {}'.format(reg.score(X_test, y_test))) 

# plot for residual error 

## setting plot style 
plt.style.use('fivethirtyeight') 

## plotting residual errors in training data 
plt.scatter(reg.predict(X_train), reg.predict(X_train) - y_train,color = "green", s = 10, label = 'Train data') 

## plotting residual errors in test data 
plt.scatter(reg.predict(X_test), reg.predict(X_test) - y_test, color = "blue", s = 10, label = 'Test data') 

## plotting line for zero residual error 
plt.hlines(y = 0, xmin = 0, xmax = 50, linewidth = 2) 

## plotting legend 
plt.legend(loc = 'upper right') 

## plot title 
plt.title("Residual errors") 

## function to show plot 
plt.show()
# Out:
# Coefficients:
#  [-8.95714048e-02  6.73132853e-02  5.04649248e-02  2.18579583e+00
#  -1.72053975e+01  3.63606995e+00  2.05579939e-03 -1.36602886e+00
#   2.89576718e-01 -1.22700072e-02 -8.34881849e-01  9.40360790e-03
#  -5.04008320e-01]
# Variance score: 0.7209056672661746

# %%
X[8]
# Out:
# array([2.1124e-01, 1.2500e+01, 7.8700e+00, 0.0000e+00, 5.2400e-01,
#        5.6310e+00, 1.0000e+02, 6.0821e+00, 5.0000e+00, 3.1100e+02,
#        1.5200e+01, 3.8663e+02, 2.9930e+01])

# %%
y[9]
# Out:
# 18.9

# %%
X_train[8]
# Out:
# array([  3.69311,   0.     ,  18.1    ,   0.     ,   0.713  ,   6.376  ,
#         88.4    ,   2.5671 ,  24.     , 666.     ,  20.2    , 391.43   ,
#         14.65   ])

# %%
for i in arr:
    if i[7]=='Do̱a Ana':
        print(i[6])
# Out:
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# New Mexico
# ...

# %%
arr[5]
# Out:
# array([1001, 'AR', 697, 1.2694192, 'USA', 18400000000003, 'Alabama',
#        'Autauga'], dtype=object)

# %%
arr[3]
# Out:
# array([1001, 'AM', 99, 0.18030488, 'USA', 18400000000003, 'Alabama',
#        'Autauga'], dtype=object)
